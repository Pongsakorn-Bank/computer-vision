# %%
from deepface import DeepFace
# import cv2
# import matplotlib.pyplot as plt

# %%
cd deepface
# Out:
# /Users/pongsakorn/Documents/GitHub/computer-vision/deepface

# %%
pwd
# Out:
# '/Users/pongsakorn/Documents/GitHub/computer-vision/deepface'

# %%
img1_path = "bank1.jpg"
img2_path = "bank2.jpg"

# %%
result = DeepFace.verify(img1_path = "job1.jpg", img2_path = "job2.jpg")
print(result)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/gg/szhk5y0x6qsc6zs46wn7g80h0000gn/T/ipykernel_46610/2682129994.py in <module>
# ----> 1 result = deepface.verify(img1_path = "job1.jpg", img2_path = "job2.jpg")
#       2 print(result)
#
# AttributeError: module 'deepface.deepface' has no attribute 'verify'
